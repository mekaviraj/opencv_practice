# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
import os
from PIL import Image

# %%
#take your face and save data
def create_user(n_id , name) :
    web = cv.VideoCapture(0)
    web.set(3,640)
    web.set(4,480)

    faces = cv.CascadeClassifier('haarcascade_frontalface_default.xml')
    
    f_dir ="dataset"
    f_name = name

    path = os.path.join(f_dir, f_name)
