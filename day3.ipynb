# %%
import cv2

# %%
img = cv2.imread(r"C:\Users\VIRAJ M\Desktop\myimg.jpg")
# The error occurs because the backslashes (\) in the file path are being interpreted as escape sequences.
# To fix it, either use a raw string (r"..."), escape the backslashes (\\), or replace them with forward slashes (/).

# %%
cv2.imshow('image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imwrite(r"C:\Users\VIRAJ M\Desktop\myimg.jpg", "img2.jpg")
#cv2.imwrite(file_path, img)
# Out:
# True

# %%
#accessing img properties
