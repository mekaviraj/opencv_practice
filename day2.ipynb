# %%
import cv2

image = cv2.imread(r"C:\Users\VIRAJ M\Desktop\myimg.jpg")


if image is None:
    print("Error: Could not load the image.")
else:
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    resized_image = cv2.resize(gray_image, (300, 300))

    cv2.imshow("Original Image", image)
    cv2.imshow("Grayscale Image", gray_image)
    cv2.imshow("Resized Grayscale Image", resized_image)

    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
img = cv2.imread("myimg.jpg",1)

# %%
cv2.imshow("myimg.jpg",img)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 cv2.imshow("myimg.jpg",img)
#
# error: OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:971: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'cv::imshow'
